# %%
#Importing the necessary libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

#Loading the dataset using sklearn
from sklearn.datasets import load_boston
data = load_boston()

#Separating data into feature variable X and target variable y respectively
X=data['data']
y=data['target']

#Extracting the names of the features from data
features = data['feature_names']

#Splitting X & y into training and testing set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.90, random_state=50)

from sklearn.ensemble import ExtraTreesRegressor
reg = ExtraTreesRegressor(n_estimators=100, random_state=0).fit(X_train, y_train)

#Checking the model's performance on the test set
print('R2 score for the model on test set =', reg.score(X_test, y_test))
# Out:
# R2 score for the model on test set = 0.9325976272434418

# %%
#Importing the module for LimeTabularExplainer
import lime.lime_tabular

#Instantiating the explainer object by passing in the training set, and the extracted features
explainer_gp_ard = lime.lime_tabular.LimeTabularExplainer(X_train,
                    feature_names=features, 
                    verbose=True, mode='regression',feature_selection='gp_ard')

#Instantiating the explainer object by passing in the training set, and the extracted features
explainer_gp_KL = lime.lime_tabular.LimeTabularExplainer(X_train,
                    feature_names=features, 
                    verbose=True, mode='regression',feature_selection='gp_KL')

#Instantiating the explainer object by passing in the training set, and the extracted features
explainer_lime = lime.lime_tabular.LimeTabularExplainer(X_train,
                    feature_names=features, 
                    verbose=True, mode='regression',feature_selection='lasso_path')

#Index corresponding to the test vector
i = 20

#Number denoting the top features; For the purposes of this experiment we've taken into account all features
k = X_train.shape[1]

num_samples_list = [50, 100, 200, 250, 300, 350, 400, 450, 500]

dict_lime={}
dict_gp_ard={}
dict_gp_KL = {}

# %%
for val in num_samples_list:
    temp_dict = {}
    for iteration in range(100):
        print(f"Performing experiment for LIME(default settings) num_samples = {val}, iteration = {iteration}")

        exp_lime = explainer_lime.explain_instance(X_test[i], reg.predict, num_features=k, num_samples=val)

        for feature in exp_lime.as_list():
            if feature[0] in temp_dict.keys():
                temp_dict[feature[0]].append(feature[1])
            else:
                temp_dict[feature[0]] = [feature[1]]
    
    dict_lime[val] = temp_dict
    
    temp_dict = {}
    for iteration in range(100):
        print(f"-->> Performing experiment for LIME(gp_ard) num_samples = {val}, iteration = {iteration}")
        exp_gp_ard = explainer_gp_ard.explain_instance(X_test[i], reg.predict, num_features=k, num_samples=val)

        for feature in exp_gp_ard.as_list():
            if feature[0] in temp_dict.keys():
                temp_dict[feature[0]].append(feature[1])
            else:
                temp_dict[feature[0]] = [feature[1]]
    
    dict_gp_ard[val] = temp_dict
    
    temp_dict = {}
    for iteration in range(100):
        print(f"-->> Performing experiment for LIME(gp_KL) num_samples = {val}, iteration = {iteration}")
        exp_gp_KL = explainer_gp_KL.explain_instance(X_test[i], reg.predict, num_features=k, num_samples=val)

        for feature in exp_gp_KL.as_list():
            if feature[0] in temp_dict.keys():
                temp_dict[feature[0]].append(feature[1])
            else:
                temp_dict[feature[0]] = [feature[1]]
    
    dict_gp_KL[val] = temp_dict
# Out:
# Performing experiment for LIME(default settings) num_samples = 50, iteration = 0
# Intercept 22.134016997651795
# Prediction_local [20.77879276]
# Right: 21.932999999999996
# Performing experiment for LIME(default settings) num_samples = 50, iteration = 1
# Intercept 21.31964060627992
# Prediction_local [21.47945929]
# Right: 21.932999999999996
# Performing experiment for LIME(default settings) num_samples = 50, iteration = 2
# Intercept 22.311119054498555
# Prediction_local [23.27192968]
# Right: 21.932999999999996
# Performing experiment for LIME(default settings) num_samples = 50, iteration = 3
# Intercept 25.109477847813878
# Prediction_local [20.43823362]
# Right: 21.932999999999996
# Performing experiment for LIME(default settings) num_samples = 50, iteration = 4
# Intercept 25.371663599010336
# Prediction_local [19.74414783]
# Right: 21.932999999999996
# Performing experiment for LIME(default settings) num_samples = 50, iteration = 5
# Intercept 22.146500637427806
# Prediction_local [23.45121636]
# Right: 21.932999999999996
# Performing experiment for LIME(default settings) num_samples = 50, iteration = 6
# Intercept 27.249387639391152
# Prediction_local [22.41116276]
# Right: 21.932999999999996
# Performing experiment for LIME(default settings) num_samples = 50, iteration = 7
# Intercept 22.677262722647942
# Prediction_local [24.53382857]
# Right: 21.932999999999996
# Performing experiment for LIME(default settings) num_samples = 50, iteration = 8
# Intercept 21.183446677991263
# Prediction_local [22.13380202]
# Right: 21.932999999999996
# Performing experiment for LIME(default settings) num_samples = 50, iteration = 9
# Intercept 22.590695684058442
# Prediction_local [23.9101496]
# Right: 21.932999999999996
# Performing experiment for LIME(default settings) num_samples = 50, iteration = 10
# Intercept 26.27660717502171
# Prediction_local [22.51843997]
# Right: 21.932999999999996
# Performing experiment for LIME(default settings) num_samples = 50, iteration = 11
# Intercept 26.647309335819138
# Prediction_local [23.5507754]
# Right: 21.932999999999996
# Performing experiment for LIME(default settings) num_samples = 50, iteration = 12
# Intercept 25.746584147837375
# Prediction_local [19.40340542]
# Right: 21.932999999999996
# Performing experiment for LIME(default settings) num_samples = 50, iteration = 13
# Intercept 27.612279111247386
# Prediction_local [21.34309196]
# Right: 21.932999999999996
# Performing experiment for LIME(default settings) num_samples = 50, iteration = 14
# Intercept 25.83268637951745
# Prediction_local [20.93771507]
# Right: 21.932999999999996
# Performing experiment for LIME(default settings) num_samples = 50, iteration = 15
# Intercept 22.458903838502646
# Prediction_local [21.58864283]
# Right: 21.932999999999996
# Performing experiment for LIME(default settings) num_samples = 50, iteration = 16
# Intercept 24.073350598600953
# Prediction_local [17.24474939]
# Right: 21.932999999999996
# Performing experiment for LIME(default settings) num_samples = 50, iteration = 17
# Intercept 24.556301756140137
# Prediction_local [23.9806226]
# Right: 21.932999999999996
# Performing experiment for LIME(default settings) num_samples = 50, iteration = 18
# Intercept 22.524473161100627
# Prediction_local [21.99962293]
# Right: 21.932999999999996
# Performing experiment for LIME(default settings) num_samples = 50, iteration = 19
# Intercept 28.686844599649604
# Prediction_local [20.30508972]
# Right: 21.932999999999996
# Performing experiment for LIME(default settings) num_samples = 50, iteration = 20
# Intercept 25.19634546350637
# Prediction_local [23.07047011]
# Right: 21.932999999999996
# Performing experiment for LIME(default settings) num_samples = 50, iteration = 21
# Intercept 25.250354032118246
# Prediction_local [21.84535642]
# Right: 21.932999999999996
# Performing experiment for LIME(default settings) num_samples = 50, iteration = 22
# Intercept 22.481517850223156
# Prediction_local [21.24812157]
# Right: 21.932999999999996
# Performing experiment for LIME(default settings) num_samples = 50, iteration = 23
# Intercept 23.446277726029038
# Prediction_local [21.30183631]
# Right: 21.932999999999996
# Performing experiment for LIME(default settings) num_samples = 50, iteration = 24
# Intercept 23.160694485388284
# Prediction_local [19.86576679]
# Right: 21.932999999999996
# Performing experiment for LIME(default settings) num_samples = 50, iteration = 25
# Intercept 24.913901069124407
# Prediction_local [22.0708533]
# Right: 21.932999999999996
# Performing experiment for LIME(default settings) num_samples = 50, iteration = 26
# Intercept 25.075882067746605
# Prediction_local [22.02532951]
# Right: 21.932999999999996
# Performing experiment for LIME(default settings) num_samples = 50, iteration = 27
# Intercept 25.125718085142726
# Prediction_local [21.72742201]
# Right: 21.932999999999996
# Performing experiment for LIME(default settings) num_samples = 50, iteration = 28
# Intercept 25.016733884184003
# Prediction_local [22.47314218]
# Right: 21.932999999999996
# Performing experiment for LIME(default settings) num_samples = 50, iteration = 29
# Intercept 24.63308774364296
# Prediction_local [20.49722874]
# Right: 21.932999999999996
# Performing experiment for LIME(default settings) num_samples = 50, iteration = 30
# Intercept 23.85236693441214
# Prediction_local [20.56430461]
# Right: 21.932999999999996
# Performing experiment for LIME(default settings) num_samples = 50, iteration = 31
# Intercept 24.87543576666013
# Prediction_local [18.6570013]
# Right: 21.932999999999996
# Performing experiment for LIME(default settings) num_samples = 50, iteration = 32
# Intercept 23.988167682330275
# Prediction_local [19.58536814]
# Right: 21.932999999999996
# Performing experiment for LIME(default settings) num_samples = 50, iteration = 33
# Intercept 23.321523605522998
# Prediction_local [21.51704822]
# Right: 21.932999999999996
# Performing experiment for LIME(default settings) num_samples = 50, iteration = 34
# Intercept 22.17937187074105
# Prediction_local [24.17525315]
# Right: 21.932999999999996
# Performing experiment for LIME(default settings) num_samples = 50, iteration = 35
# Intercept 26.38844178946871
# Prediction_local [23.07996177]
# Right: 21.932999999999996
# Performing experiment for LIME(default settings) num_samples = 50, iteration = 36
# Intercept 24.5039946852835
# Prediction_local [22.57129798]
# Right: 21.932999999999996
# Performing experiment for LIME(default settings) num_samples = 50, iteration = 37
# Intercept 26.746301924143744
# Prediction_local [20.2861349]
# Right: 21.932999999999996
# Performing experiment for LIME(default settings) num_samples = 50, iteration = 38
# Intercept 29.56568489861592
# Prediction_local [20.01286769]
# Right: 21.932999999999996
# Performing experiment for LIME(default settings) num_samples = 50, iteration = 39
# Intercept 21.33260374368357
# Prediction_local [21.78460883]
# Right: 21.932999999999996
# Performing experiment for LIME(default settings) num_samples = 50, iteration = 40
# Intercept 21.369568433914885
# Prediction_local [20.50608867]
# Right: 21.932999999999996
# Performing experiment for LIME(default settings) num_samples = 50, iteration = 41
# Intercept 23.736502208740188
# Prediction_local [22.87018392]
# Right: 21.932999999999996
# Performing experiment for LIME(default settings) num_samples = 50, iteration = 42
# Intercept 21.737835345525728
# Prediction_local [23.23782262]
# Right: 21.932999999999996
# Performing experiment for LIME(default settings) num_samples = 50, iteration = 43
# Intercept 25.310199630682398
# Prediction_local [19.08636919]
# Right: 21.932999999999996
# Performing experiment for LIME(default settings) num_samples = 50, iteration = 44
# Intercept 25.583155969465313
# Prediction_local [18.99289443]
# Right: 21.932999999999996
# Performing experiment for LIME(default settings) num_samples = 50, iteration = 45
# Intercept 20.627494313845723
# Prediction_local [25.04717485]
# Right: 21.932999999999996
# Performing experiment for LIME(default settings) num_samples = 50, iteration = 46
# Intercept 22.632753143691822
# Prediction_local [20.59492489]
# Right: 21.932999999999996
# Performing experiment for LIME(default settings) num_samples = 50, iteration = 47
# Intercept 25.362296427760253
# Prediction_local [22.44040007]
# Right: 21.932999999999996
# Performing experiment for LIME(default settings) num_samples = 50, iteration = 48
# Intercept 26.17150528574943
# Prediction_local [21.93563297]
# Right: 21.932999999999996
# Performing experiment for LIME(default settings) num_samples = 50, iteration = 49
# Intercept 25.614257976490112
# Prediction_local [18.94788276]
# Right: 21.932999999999996
# Performing experiment for LIME(default settings) num_samples = 50, iteration = 50
# Intercept 23.847681272030925
# Prediction_local [22.51711448]
# Right: 21.932999999999996
# Performing experiment for LIME(default settings) num_samples = 50, iteration = 51
# Intercept 22.733144605393267
# Prediction_local [21.71008446]
# Right: 21.932999999999996
# Performing experiment for LIME(default settings) num_samples = 50, iteration = 52
# Intercept 25.887560707546267
# Prediction_local [22.2467752]
# Right: 21.932999999999996
# Performing experiment for LIME(default settings) num_samples = 50, iteration = 53
# Intercept 28.1779040916324
# Prediction_local [21.35721398]
# Right: 21.932999999999996
# Performing experiment for LIME(default settings) num_samples = 50, iteration = 54
# Intercept 22.504805266535612
# Prediction_local [21.20861489]
# Right: 21.932999999999996
# Performing experiment for LIME(default settings) num_samples = 50, iteration = 55
# Intercept 20.585543918501017
# Prediction_local [22.53604221]
# Right: 21.932999999999996
# Performing experiment for LIME(default settings) num_samples = 50, iteration = 56
# Intercept 20.599266703609672
# Prediction_local [20.64188037]
# Right: 21.932999999999996
# Performing experiment for LIME(default settings) num_samples = 50, iteration = 57
# Intercept 20.73875638144301
# Prediction_local [22.36491062]
# Right: 21.932999999999996
# Performing experiment for LIME(default settings) num_samples = 50, iteration = 58
# Intercept 25.343870583541474
# Prediction_local [22.27138721]
# Right: 21.932999999999996
# Performing experiment for LIME(default settings) num_samples = 50, iteration = 59
# Intercept 22.626596804097638
# Prediction_local [21.81529284]
# Right: 21.932999999999996
# Performing experiment for LIME(default settings) num_samples = 50, iteration = 60
# Intercept 26.611730946932667
# Prediction_local [19.96785885]
# Right: 21.932999999999996
# Performing experiment for LIME(default settings) num_samples = 50, iteration = 61
# Intercept 24.1680089069512
# Prediction_local [22.20604235]
# Right: 21.932999999999996
# Performing experiment for LIME(default settings) num_samples = 50, iteration = 62
# Intercept 28.996978252517398
# Prediction_local [20.60234443]
# Right: 21.932999999999996
# Performing experiment for LIME(default settings) num_samples = 50, iteration = 63
# Intercept 26.22876507510469
# Prediction_local [22.42653158]
# Right: 21.932999999999996
# Performing experiment for LIME(default settings) num_samples = 50, iteration = 64
# Intercept 27.066091195650067
# Prediction_local [19.5990749]
# Right: 21.932999999999996
# Performing experiment for LIME(default settings) num_samples = 50, iteration = 65
# Intercept 26.400828682880032
# Prediction_local [21.55142567]
# Right: 21.932999999999996
# Performing experiment for LIME(default settings) num_samples = 50, iteration = 66
# Intercept 23.58162038753002
# Prediction_local [23.29278818]
# Right: 21.932999999999996
# Performing experiment for LIME(default settings) num_samples = 50, iteration = 67
# Intercept 22.612261311729068
# Prediction_local [21.05064501]
# Right: 21.932999999999996
# Performing experiment for LIME(default settings) num_samples = 50, iteration = 68
# Intercept 26.667268479516817
# Prediction_local [22.88066711]
# Right: 21.932999999999996
# Performing experiment for LIME(default settings) num_samples = 50, iteration = 69
# Intercept 23.21770612532569
# Prediction_local [20.28140615]
# Right: 21.932999999999996
# Performing experiment for LIME(default settings) num_samples = 50, iteration = 70
# Intercept 24.885924069681778
# Prediction_local [20.86538911]
# Right: 21.932999999999996
# Performing experiment for LIME(default settings) num_samples = 50, iteration = 71
# Intercept 27.132707064192427
# Prediction_local [19.7313785]
# Right: 21.932999999999996
# Performing experiment for LIME(default settings) num_samples = 50, iteration = 72
# Intercept 26.16649877129542
# Prediction_local [23.05300103]
# Right: 21.932999999999996
# Performing experiment for LIME(default settings) num_samples = 50, iteration = 73
# Intercept 27.128935426150676
# Prediction_local [21.26801392]
# Right: 21.932999999999996
# Performing experiment for LIME(default settings) num_samples = 50, iteration = 74
# Intercept 25.4892424941859
# Prediction_local [23.66968986]
# Right: 21.932999999999996
# Performing experiment for LIME(default settings) num_samples = 50, iteration = 75
# Intercept 26.78657863330207
# Prediction_local [21.73938112]
# Right: 21.932999999999996
# Performing experiment for LIME(default settings) num_samples = 50, iteration = 76
# Intercept 20.98033193261866
# Prediction_local [21.92109742]
# Right: 21.932999999999996
# Performing experiment for LIME(default settings) num_samples = 50, iteration = 77
# Intercept 20.004839139848453
# Prediction_local [20.85909767]
# Right: 21.932999999999996
# Performing experiment for LIME(default settings) num_samples = 50, iteration = 78
# Intercept 23.218659292043004
# Prediction_local [23.62313136]
# Right: 21.932999999999996
# Performing experiment for LIME(default settings) num_samples = 50, iteration = 79
# Intercept 26.49967807918405
# Prediction_local [20.51249181]
# Right: 21.932999999999996
# Performing experiment for LIME(default settings) num_samples = 50, iteration = 80
# Intercept 28.36749523296082
# Prediction_local [22.49908278]
# Right: 21.932999999999996
# Performing experiment for LIME(default settings) num_samples = 50, iteration = 81
# Intercept 25.517712286180632
# Prediction_local [21.81626486]
# Right: 21.932999999999996
# Performing experiment for LIME(default settings) num_samples = 50, iteration = 82
# Intercept 20.5689920485714
# Prediction_local [24.42622914]
# Right: 21.932999999999996
# Performing experiment for LIME(default settings) num_samples = 50, iteration = 83
# Intercept 26.043745421711293
# Prediction_local [22.53318768]
# Right: 21.932999999999996
# Performing experiment for LIME(default settings) num_samples = 50, iteration = 84
# Intercept 22.971196633028
# Prediction_local [21.78950167]
# Right: 21.932999999999996
# Performing experiment for LIME(default settings) num_samples = 50, iteration = 85
# Intercept 24.37527909416331
# Prediction_local [21.72176863]
# Right: 21.932999999999996
# Performing experiment for LIME(default settings) num_samples = 50, iteration = 86
# Intercept 21.48466353556863
# Prediction_local [22.00327847]
# Right: 21.932999999999996
# Performing experiment for LIME(default settings) num_samples = 50, iteration = 87
# Intercept 22.300064670520342
# Prediction_local [23.27280524]
# Right: 21.932999999999996
# Performing experiment for LIME(default settings) num_samples = 50, iteration = 88
# Intercept 25.229495298569386
# Prediction_local [19.88270906]
# Right: 21.932999999999996
# Performing experiment for LIME(default settings) num_samples = 50, iteration = 89
# Intercept 22.15767713726853
# Prediction_local [23.69166479]
# Right: 21.932999999999996
# Performing experiment for LIME(default settings) num_samples = 50, iteration = 90
# Intercept 25.637896166229307
# Prediction_local [19.26642021]
# Right: 21.932999999999996
# Performing experiment for LIME(default settings) num_samples = 50, iteration = 91
# Intercept 23.892826259333983
# Prediction_local [22.2946598]
# Right: 21.932999999999996
# Performing experiment for LIME(default settings) num_samples = 50, iteration = 92
# Intercept 24.761244564084226
# Prediction_local [22.33121825]
# Right: 21.932999999999996
# Performing experiment for LIME(default settings) num_samples = 50, iteration = 93
# Intercept 27.799606418400913
# Prediction_local [22.42635704]
# Right: 21.932999999999996
# Performing experiment for LIME(default settings) num_samples = 50, iteration = 94
# Intercept 22.78371979857045
# Prediction_local [20.93844666]
# Right: 21.932999999999996
# Performing experiment for LIME(default settings) num_samples = 50, iteration = 95
# Intercept 27.173853104278926
# Prediction_local [18.37370688]
# Right: 21.932999999999996
# Performing experiment for LIME(default settings) num_samples = 50, iteration = 96
# Intercept 22.038719348815825
# Prediction_local [20.92407691]
# Right: 21.932999999999996
# Performing experiment for LIME(default settings) num_samples = 50, iteration = 97
# Intercept 26.00835510366552
# Prediction_local [23.48631962]
# Right: 21.932999999999996
# Performing experiment for LIME(default settings) num_samples = 50, iteration = 98
# Intercept 25.02592072881359
# Prediction_local [21.80640221]
# Right: 21.932999999999996
# Performing experiment for LIME(default settings) num_samples = 50, iteration = 99
# Intercept 24.580489451678137
# Prediction_local [24.43588029]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_ard) num_samples = 50, iteration = 0
# Intercept 23.501348180906366
# Prediction_local [22.01347225]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_ard) num_samples = 50, iteration = 1
# Intercept 22.22545230844283
# Prediction_local [20.2800638]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_ard) num_samples = 50, iteration = 2
# Intercept 22.0125403477511
# Prediction_local [23.41812773]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_ard) num_samples = 50, iteration = 3
# Intercept 24.86128705108623
# Prediction_local [22.26378974]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_ard) num_samples = 50, iteration = 4
# Intercept 27.20554428430233
# Prediction_local [19.51033642]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_ard) num_samples = 50, iteration = 5
# Intercept 24.759172518050534
# Prediction_local [21.05093039]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_ard) num_samples = 50, iteration = 6
# Intercept 22.677846057715108
# Prediction_local [20.18946448]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_ard) num_samples = 50, iteration = 7
# Intercept 20.99989574417966
# Prediction_local [22.61321502]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_ard) num_samples = 50, iteration = 8
# Intercept 20.70182381160397
# Prediction_local [24.60217596]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_ard) num_samples = 50, iteration = 9
# Intercept 24.163269890996872
# Prediction_local [23.62614675]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_ard) num_samples = 50, iteration = 10
# Intercept 22.240587444393984
# Prediction_local [24.81817247]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_ard) num_samples = 50, iteration = 11
# Intercept 25.65203992582812
# Prediction_local [18.64818962]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_ard) num_samples = 50, iteration = 12
# Intercept 23.51996404828761
# Prediction_local [21.4216555]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_ard) num_samples = 50, iteration = 13
# Intercept 25.893833744259613
# Prediction_local [18.48486104]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_ard) num_samples = 50, iteration = 14
# Intercept 23.284113815971054
# Prediction_local [21.49974704]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_ard) num_samples = 50, iteration = 15
# Intercept 22.582944987938127
# Prediction_local [22.74193699]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_ard) num_samples = 50, iteration = 16
# Intercept 24.098747914030273
# Prediction_local [20.78498969]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_ard) num_samples = 50, iteration = 17
# Intercept 24.39627293551977
# Prediction_local [22.68892088]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_ard) num_samples = 50, iteration = 18
# Intercept 25.04581856085762
# Prediction_local [22.2622653]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_ard) num_samples = 50, iteration = 19
# Intercept 28.112746342407195
# Prediction_local [18.81759247]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_ard) num_samples = 50, iteration = 20
# Intercept 22.58212996757968
# Prediction_local [21.85164179]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_ard) num_samples = 50, iteration = 21
# Intercept 23.465600185205677
# Prediction_local [22.06265875]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_ard) num_samples = 50, iteration = 22
# Intercept 26.86795952756357
# Prediction_local [19.40327369]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_ard) num_samples = 50, iteration = 23
# Intercept 25.686186331744047
# Prediction_local [18.92577619]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_ard) num_samples = 50, iteration = 24
# Intercept 25.36577275175896
# Prediction_local [22.37786544]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_ard) num_samples = 50, iteration = 25
# Intercept 21.710393545985468
# Prediction_local [20.89837124]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_ard) num_samples = 50, iteration = 26
# Intercept 25.773037125875057
# Prediction_local [20.97512771]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_ard) num_samples = 50, iteration = 27
# Intercept 29.473594452940397
# Prediction_local [18.99412927]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_ard) num_samples = 50, iteration = 28
# Intercept 25.154662481040532
# Prediction_local [22.89271129]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_ard) num_samples = 50, iteration = 29
# Intercept 24.181018941467972
# Prediction_local [21.91956735]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_ard) num_samples = 50, iteration = 30
# Intercept 26.91726870174032
# Prediction_local [20.96601201]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_ard) num_samples = 50, iteration = 31
# Intercept 26.32883607585192
# Prediction_local [22.28739564]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_ard) num_samples = 50, iteration = 32
# Intercept 22.225949377561477
# Prediction_local [22.42246076]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_ard) num_samples = 50, iteration = 33
# Intercept 24.436329125075936
# Prediction_local [20.42442852]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_ard) num_samples = 50, iteration = 34
# Intercept 21.45644075191702
# Prediction_local [23.70021599]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_ard) num_samples = 50, iteration = 35
# Intercept 21.102953161675778
# Prediction_local [22.87440975]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_ard) num_samples = 50, iteration = 36
# Intercept 19.9973124530101
# Prediction_local [23.01943786]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_ard) num_samples = 50, iteration = 37
# Intercept 25.4058357370892
# Prediction_local [18.18334043]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_ard) num_samples = 50, iteration = 38
# Intercept 27.099462512230698
# Prediction_local [21.38594597]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_ard) num_samples = 50, iteration = 39
# Intercept 25.131007179100916
# Prediction_local [24.10160387]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_ard) num_samples = 50, iteration = 40
# Intercept 21.886709410368013
# Prediction_local [19.1753872]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_ard) num_samples = 50, iteration = 41
# Intercept 23.13583908845274
# Prediction_local [18.86445812]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_ard) num_samples = 50, iteration = 42
# Intercept 19.246323900292357
# Prediction_local [23.45379042]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_ard) num_samples = 50, iteration = 43
# Intercept 24.073978783618962
# Prediction_local [21.8276757]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_ard) num_samples = 50, iteration = 44
# Intercept 25.293100953426848
# Prediction_local [22.98803997]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_ard) num_samples = 50, iteration = 45
# Intercept 23.42758719748148
# Prediction_local [19.69179291]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_ard) num_samples = 50, iteration = 46
# Intercept 24.762744413921244
# Prediction_local [20.37796497]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_ard) num_samples = 50, iteration = 47
# Intercept 22.29309470657041
# Prediction_local [21.05362812]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_ard) num_samples = 50, iteration = 48
# Intercept 24.845835361712798
# Prediction_local [21.04452675]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_ard) num_samples = 50, iteration = 49
# Intercept 27.56323266486745
# Prediction_local [20.69186477]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_ard) num_samples = 50, iteration = 50
# Intercept 24.640706210047053
# Prediction_local [24.21629134]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_ard) num_samples = 50, iteration = 51
# Intercept 24.196428813936535
# Prediction_local [22.23533671]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_ard) num_samples = 50, iteration = 52
# Intercept 26.27620849537246
# Prediction_local [22.07832734]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_ard) num_samples = 50, iteration = 53
# Intercept 24.734473200509804
# Prediction_local [20.23962584]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_ard) num_samples = 50, iteration = 54
# Intercept 23.27693491704418
# Prediction_local [21.38498996]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_ard) num_samples = 50, iteration = 55
# Intercept 24.851892326067876
# Prediction_local [22.45700764]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_ard) num_samples = 50, iteration = 56
# Intercept 23.02695745438465
# Prediction_local [21.75244924]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_ard) num_samples = 50, iteration = 57
# Intercept 24.237526805569203
# Prediction_local [21.73103558]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_ard) num_samples = 50, iteration = 58
# Intercept 26.311386873458154
# Prediction_local [21.90378959]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_ard) num_samples = 50, iteration = 59
#  C:\Users\adity\anaconda3\lib\site-packages\GPy\kern\src\stationary.py:137: RuntimeWarning:overflow encountered in square
#  C:\Users\adity\anaconda3\lib\site-packages\GPy\kern\src\stationary.py:138: RuntimeWarning:invalid value encountered in add
# Intercept 25.522904793687662
# Prediction_local [21.30397682]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_ard) num_samples = 50, iteration = 60
# Intercept 21.264975759308445
# Prediction_local [20.02392777]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_ard) num_samples = 50, iteration = 61
# Intercept 23.821559665770774
# Prediction_local [25.70019069]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_ard) num_samples = 50, iteration = 62
# Intercept 22.310958056718338
# Prediction_local [22.94184752]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_ard) num_samples = 50, iteration = 63
# Intercept 23.740748400189936
# Prediction_local [20.86306396]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_ard) num_samples = 50, iteration = 64
# Intercept 25.20839379493424
# Prediction_local [20.56534759]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_ard) num_samples = 50, iteration = 65
# Intercept 25.153580165711233
# Prediction_local [21.562492]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_ard) num_samples = 50, iteration = 66
# Intercept 28.96035666761656
# Prediction_local [20.31955723]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_ard) num_samples = 50, iteration = 67
# Intercept 25.213803509601075
# Prediction_local [23.48432953]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_ard) num_samples = 50, iteration = 68
# Intercept 24.272905971889514
# Prediction_local [20.47833284]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_ard) num_samples = 50, iteration = 69
# Intercept 25.15913256018723
# Prediction_local [21.02699208]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_ard) num_samples = 50, iteration = 70
# Intercept 28.90626089239809
# Prediction_local [21.06815005]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_ard) num_samples = 50, iteration = 71
# Intercept 19.89082772478664
# Prediction_local [22.87905288]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_ard) num_samples = 50, iteration = 72
# Intercept 23.418072151679162
# Prediction_local [20.34105695]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_ard) num_samples = 50, iteration = 73
# Intercept 25.927261750748237
# Prediction_local [22.70725705]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_ard) num_samples = 50, iteration = 74
# Intercept 25.501752164094956
# Prediction_local [21.04087285]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_ard) num_samples = 50, iteration = 75
# Intercept 19.868075149409528
# Prediction_local [23.5471406]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_ard) num_samples = 50, iteration = 76
# Intercept 25.070303969480175
# Prediction_local [25.01935488]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_ard) num_samples = 50, iteration = 77
# Intercept 24.7081493499834
# Prediction_local [20.79257198]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_ard) num_samples = 50, iteration = 78
# Intercept 25.147145321877595
# Prediction_local [21.51003482]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_ard) num_samples = 50, iteration = 79
# Intercept 24.747431949217948
# Prediction_local [20.80547679]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_ard) num_samples = 50, iteration = 80
# Intercept 26.198397887268833
# Prediction_local [21.345298]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_ard) num_samples = 50, iteration = 81
# Intercept 25.25820916033187
# Prediction_local [21.81043393]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_ard) num_samples = 50, iteration = 82
# Intercept 23.59820970538228
# Prediction_local [21.73155318]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_ard) num_samples = 50, iteration = 83
# Intercept 20.036295576838175
# Prediction_local [24.16491742]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_ard) num_samples = 50, iteration = 84
# Intercept 26.95631734544841
# Prediction_local [20.05823572]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_ard) num_samples = 50, iteration = 85
# Intercept 25.326891754892742
# Prediction_local [21.16498311]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_ard) num_samples = 50, iteration = 86
# Intercept 22.842254051755233
# Prediction_local [20.22923806]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_ard) num_samples = 50, iteration = 87
# Intercept 25.263227561510064
# Prediction_local [24.90250815]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_ard) num_samples = 50, iteration = 88
# Intercept 22.906479460297806
# Prediction_local [21.53631016]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_ard) num_samples = 50, iteration = 89
# Intercept 24.58200988460564
# Prediction_local [18.40694135]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_ard) num_samples = 50, iteration = 90
# Intercept 24.105306260262417
# Prediction_local [21.98968296]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_ard) num_samples = 50, iteration = 91
# Intercept 24.16523717489616
# Prediction_local [22.38802365]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_ard) num_samples = 50, iteration = 92
# Intercept 23.80720968586579
# Prediction_local [21.59501611]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_ard) num_samples = 50, iteration = 93
# Intercept 21.613948686421168
# Prediction_local [22.36375272]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_ard) num_samples = 50, iteration = 94
# Intercept 22.54570595657677
# Prediction_local [20.41096085]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_ard) num_samples = 50, iteration = 95
# Intercept 25.125495733012958
# Prediction_local [19.13287254]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_ard) num_samples = 50, iteration = 96
# Intercept 21.991875201332498
# Prediction_local [19.95434571]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_ard) num_samples = 50, iteration = 97
# Intercept 19.784558467561475
# Prediction_local [24.01031465]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_ard) num_samples = 50, iteration = 98
# Intercept 22.280459493307234
# Prediction_local [21.69507674]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_ard) num_samples = 50, iteration = 99
# Intercept 25.72697318135942
# Prediction_local [19.62802332]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 50, iteration = 0
# Intercept 22.426687514611608
# Prediction_local [22.91455466]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 50, iteration = 1
# Intercept 25.267558764518732
# Prediction_local [21.1950779]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 50, iteration = 2
# Intercept 24.756646221093735
# Prediction_local [25.83867219]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 50, iteration = 3
# Intercept 25.8328435706237
# Prediction_local [20.11404521]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 50, iteration = 4
# Intercept 25.249844828380056
# Prediction_local [18.72425988]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 50, iteration = 5
# Intercept 20.023001670980875
# Prediction_local [22.85923694]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 50, iteration = 6
# Intercept 23.42404579006522
# Prediction_local [21.86893745]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 50, iteration = 7
# Intercept 25.275769512641915
# Prediction_local [21.7959445]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 50, iteration = 8
# Intercept 30.20379333248626
# Prediction_local [21.13626739]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 50, iteration = 9
# Intercept 22.468411927723395
# Prediction_local [19.71915383]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 50, iteration = 10
# Intercept 23.947213314711274
# Prediction_local [22.58459187]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 50, iteration = 11
# Intercept 21.37402751846706
# Prediction_local [21.88009153]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 50, iteration = 12
# Intercept 22.620632381150234
# Prediction_local [24.6572334]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 50, iteration = 13
# Intercept 22.02145600694273
# Prediction_local [22.02887288]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 50, iteration = 14
# Intercept 26.386507803727774
# Prediction_local [21.78408157]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 50, iteration = 15
# Intercept 25.01118504884025
# Prediction_local [20.5477819]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 50, iteration = 16
# Intercept 26.504266841261778
# Prediction_local [22.49685332]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 50, iteration = 17
# Intercept 23.812782292339236
# Prediction_local [19.30206156]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 50, iteration = 18
# Intercept 23.241262512581308
# Prediction_local [21.67667984]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 50, iteration = 19
# Intercept 21.1541427729909
# Prediction_local [20.56310805]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 50, iteration = 20
# Intercept 26.53637721414529
# Prediction_local [18.9256159]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 50, iteration = 21
# Intercept 26.257385947322124
# Prediction_local [19.27182836]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 50, iteration = 22
# Intercept 23.643489457349723
# Prediction_local [19.86728905]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 50, iteration = 23
# Intercept 23.090087472506355
# Prediction_local [18.9963573]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 50, iteration = 24
# Intercept 22.551429910550706
# Prediction_local [21.24029043]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 50, iteration = 25
# Intercept 23.606354474712198
# Prediction_local [20.51549852]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 50, iteration = 26
# Intercept 19.322950561595906
# Prediction_local [22.37240957]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 50, iteration = 27
# Intercept 23.889079106466014
# Prediction_local [21.52057879]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 50, iteration = 28
# Intercept 27.712799040984756
# Prediction_local [21.99602942]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 50, iteration = 29
# Intercept 23.634791910787253
# Prediction_local [21.27580939]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 50, iteration = 30
# Intercept 23.05733937293246
# Prediction_local [24.23791708]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 50, iteration = 31
# Intercept 22.85744972656311
# Prediction_local [21.9998296]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 50, iteration = 32
# Intercept 21.663509473461794
# Prediction_local [21.5066286]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 50, iteration = 33
# Intercept 25.167957847391186
# Prediction_local [21.10726976]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 50, iteration = 34
# Intercept 23.59877755353746
# Prediction_local [21.49851094]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 50, iteration = 35
# Intercept 25.526546744657185
# Prediction_local [21.14061032]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 50, iteration = 36
# Intercept 24.43895722955854
# Prediction_local [20.94833134]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 50, iteration = 37
# Intercept 25.083534630398805
# Prediction_local [20.44071814]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 50, iteration = 38
# Intercept 26.15416596661462
# Prediction_local [22.64330717]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 50, iteration = 39
# Intercept 24.613362921601908
# Prediction_local [20.49305411]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 50, iteration = 40
# Intercept 22.977529899877286
# Prediction_local [19.97689143]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 50, iteration = 41
# Intercept 27.119748392330184
# Prediction_local [20.60703511]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 50, iteration = 42
# Intercept 26.532458568360212
# Prediction_local [19.44965407]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 50, iteration = 43
# Intercept 25.17608556890091
# Prediction_local [22.53871318]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 50, iteration = 44
# Intercept 22.98728348016196
# Prediction_local [21.2880504]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 50, iteration = 45
# Intercept 22.8618627101968
# Prediction_local [21.49942708]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 50, iteration = 46
# Intercept 28.91993391122171
# Prediction_local [19.22127621]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 50, iteration = 47
# Intercept 20.78764908895776
# Prediction_local [22.86647411]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 50, iteration = 48
# Intercept 22.415877944451655
# Prediction_local [20.05983655]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 50, iteration = 49
# Intercept 21.524210454815123
# Prediction_local [22.8038635]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 50, iteration = 50
# Intercept 29.53015849654618
# Prediction_local [21.96132221]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 50, iteration = 51
# Intercept 24.225741816127268
# Prediction_local [20.25209246]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 50, iteration = 52
# Intercept 23.724432991652222
# Prediction_local [22.7285739]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 50, iteration = 53
# Intercept 26.20409616081389
# Prediction_local [18.96532011]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 50, iteration = 54
# Intercept 28.57089483379989
# Prediction_local [21.54516584]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 50, iteration = 55
# Intercept 23.20015527882295
# Prediction_local [21.48881616]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 50, iteration = 56
# Intercept 24.207232374260784
# Prediction_local [19.36315902]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 50, iteration = 57
# Intercept 23.898531085271266
# Prediction_local [23.35815653]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 50, iteration = 58
# Intercept 20.761513346661914
# Prediction_local [21.54170083]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 50, iteration = 59
# Intercept 24.828111708758417
# Prediction_local [20.11799019]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 50, iteration = 60
# Intercept 22.52593093808121
# Prediction_local [19.34370918]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 50, iteration = 61
# Intercept 24.886609882937858
# Prediction_local [18.61497941]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 50, iteration = 62
# Intercept 27.096948814983854
# Prediction_local [19.10547]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 50, iteration = 63
# Intercept 24.637842565085748
# Prediction_local [22.8359039]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 50, iteration = 64
# Intercept 24.360493354817
# Prediction_local [19.6979269]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 50, iteration = 65
# Intercept 26.66584066956347
# Prediction_local [21.58228223]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 50, iteration = 66
# Intercept 26.12308502244244
# Prediction_local [20.22007931]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 50, iteration = 67
# Intercept 25.757035158534478
# Prediction_local [18.75418549]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 50, iteration = 68
# Intercept 23.80401741537815
# Prediction_local [25.21452067]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 50, iteration = 69
# Intercept 21.16903605019799
# Prediction_local [22.85793739]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 50, iteration = 70
# Intercept 27.415211750266423
# Prediction_local [19.8870372]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 50, iteration = 71
# Intercept 26.128743193587557
# Prediction_local [20.07716561]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 50, iteration = 72
# Intercept 23.895863355006718
# Prediction_local [21.84261857]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 50, iteration = 73
# Intercept 22.289391606194176
# Prediction_local [22.02486926]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 50, iteration = 74
# Intercept 23.520308668840347
# Prediction_local [22.25018861]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 50, iteration = 75
# Intercept 20.893243613064627
# Prediction_local [23.26655816]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 50, iteration = 76
# Intercept 24.76361451616295
# Prediction_local [21.92986205]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 50, iteration = 77
# Intercept 23.987714956384487
# Prediction_local [22.17791872]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 50, iteration = 78
# Intercept 24.697801977807067
# Prediction_local [21.58679116]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 50, iteration = 79
# Intercept 22.2005330350126
# Prediction_local [18.71823566]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 50, iteration = 80
# Intercept 23.072487950418253
# Prediction_local [23.14467113]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 50, iteration = 81
# Intercept 23.34921147465714
# Prediction_local [22.50540367]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 50, iteration = 82
# Intercept 27.422171078171896
# Prediction_local [21.21891359]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 50, iteration = 83
# Intercept 26.563979477029125
# Prediction_local [18.21068933]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 50, iteration = 84
# Intercept 21.409920161581468
# Prediction_local [22.06039348]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 50, iteration = 85
# Intercept 24.976898945853925
# Prediction_local [24.51985092]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 50, iteration = 86
# Intercept 23.53767887280723
# Prediction_local [20.66208798]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 50, iteration = 87
# Intercept 25.424546479541934
# Prediction_local [24.85073266]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 50, iteration = 88
# Intercept 24.647062540693756
# Prediction_local [22.39376479]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 50, iteration = 89
# Intercept 27.268814104226195
# Prediction_local [20.84386289]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 50, iteration = 90
# Intercept 24.263819576446835
# Prediction_local [23.42543098]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 50, iteration = 91
# ...
# -->> Performing experiment for LIME(gp_KL) num_samples = 500, iteration = 3
# Intercept 25.394738804639843
# Prediction_local [20.01863694]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 500, iteration = 4
# Intercept 22.492330957357026
# Prediction_local [20.26902157]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 500, iteration = 5
# Intercept 25.47483746638139
# Prediction_local [20.99448159]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 500, iteration = 6
# Intercept 23.015020109981357
# Prediction_local [21.26056308]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 500, iteration = 7
# Intercept 25.21807163469208
# Prediction_local [20.64487388]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 500, iteration = 8
# Intercept 24.702060942853702
# Prediction_local [20.20117366]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 500, iteration = 9
# Intercept 25.032635434829597
# Prediction_local [20.3491759]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 500, iteration = 10
# Intercept 25.441733180827548
# Prediction_local [19.64416208]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 500, iteration = 11
# Intercept 25.027878109019444
# Prediction_local [20.79148698]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 500, iteration = 12
# Intercept 25.204664610948424
# Prediction_local [20.0844528]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 500, iteration = 13
# Intercept 24.1558880534181
# Prediction_local [20.01003448]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 500, iteration = 14
# Intercept 24.802325793446684
# Prediction_local [20.27461887]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 500, iteration = 15
# Intercept 24.42503662219244
# Prediction_local [22.07048938]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 500, iteration = 16
# Intercept 24.923504029956565
# Prediction_local [19.79968393]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 500, iteration = 17
# Intercept 24.984542140230563
# Prediction_local [20.3577529]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 500, iteration = 18
# Intercept 25.052543978967623
# Prediction_local [21.51101498]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 500, iteration = 19
# Intercept 23.717560585845167
# Prediction_local [22.5796567]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 500, iteration = 20
# Intercept 22.378292019600824
# Prediction_local [21.76198604]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 500, iteration = 21
# Intercept 26.42100756453504
# Prediction_local [18.96652422]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 500, iteration = 22
# Intercept 24.169387209681563
# Prediction_local [21.23088897]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 500, iteration = 23
# Intercept 25.7464164353366
# Prediction_local [21.40509963]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 500, iteration = 24
# Intercept 25.44515090321519
# Prediction_local [18.28337694]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 500, iteration = 25
# Intercept 22.9374080730302
# Prediction_local [22.18828177]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 500, iteration = 26
# Intercept 26.736613122310786
# Prediction_local [19.37659774]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 500, iteration = 27
# Intercept 23.25579100189132
# Prediction_local [22.01995514]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 500, iteration = 28
# Intercept 24.643724930737847
# Prediction_local [20.97237736]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 500, iteration = 29
# Intercept 23.561420621959027
# Prediction_local [21.47942505]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 500, iteration = 30
# Intercept 25.196180040671173
# Prediction_local [19.4396663]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 500, iteration = 31
# Intercept 24.08108630192469
# Prediction_local [21.31783672]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 500, iteration = 32
# Intercept 23.250905216388784
# Prediction_local [19.88492527]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 500, iteration = 33
# Intercept 25.288767196802237
# Prediction_local [20.07285838]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 500, iteration = 34
# Intercept 25.435537902890008
# Prediction_local [21.3354084]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 500, iteration = 35
# Intercept 24.510041917101997
# Prediction_local [21.41461761]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 500, iteration = 36
# Intercept 24.107371608195873
# Prediction_local [20.7927353]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 500, iteration = 37
# Intercept 25.143934602026498
# Prediction_local [19.23039452]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 500, iteration = 38
# Intercept 24.354593382630796
# Prediction_local [19.24550909]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 500, iteration = 39
# Intercept 24.48168542237432
# Prediction_local [21.4151877]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 500, iteration = 40
# Intercept 25.632254955022148
# Prediction_local [19.09833393]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 500, iteration = 41
# Intercept 24.147809136007012
# Prediction_local [20.81141519]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 500, iteration = 42
# Intercept 25.41282705824344
# Prediction_local [20.6245525]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 500, iteration = 43
# Intercept 23.59586072948937
# Prediction_local [21.7963228]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 500, iteration = 44
# Intercept 26.20320937497845
# Prediction_local [20.16593692]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 500, iteration = 45
# Intercept 24.55381583699998
# Prediction_local [20.55175297]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 500, iteration = 46
# Intercept 25.354859091570244
# Prediction_local [21.77941696]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 500, iteration = 47
# Intercept 24.697252470838283
# Prediction_local [20.91440777]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 500, iteration = 48
# Intercept 24.08226090348867
# Prediction_local [22.36904152]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 500, iteration = 49
# Intercept 23.606972269898368
# Prediction_local [21.50723948]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 500, iteration = 50
# Intercept 25.13273368445655
# Prediction_local [21.5168563]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 500, iteration = 51
# Intercept 23.74172676364022
# Prediction_local [20.88729605]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 500, iteration = 52
# Intercept 24.783852280496617
# Prediction_local [20.54282761]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 500, iteration = 53
# Intercept 24.828377272214357
# Prediction_local [21.79596311]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 500, iteration = 54
# Intercept 24.744979668127026
# Prediction_local [21.78583771]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 500, iteration = 55
# Intercept 25.208332246084346
# Prediction_local [19.78181373]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 500, iteration = 56
# Intercept 24.642377554090842
# Prediction_local [19.75163934]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 500, iteration = 57
# Intercept 25.586223429203915
# Prediction_local [20.2614054]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 500, iteration = 58
# Intercept 24.431916820805004
# Prediction_local [20.492918]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 500, iteration = 59
# Intercept 24.291736265745822
# Prediction_local [20.4474898]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 500, iteration = 60
# Intercept 23.99951338357974
# Prediction_local [20.16517727]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 500, iteration = 61
# Intercept 23.552359815108552
# Prediction_local [22.73039457]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 500, iteration = 62
# Intercept 26.296614647014234
# Prediction_local [19.68205107]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 500, iteration = 63
# Intercept 23.633309380175433
# Prediction_local [19.59698315]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 500, iteration = 64
# Intercept 23.727229796145743
# Prediction_local [22.67834372]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 500, iteration = 65
# Intercept 24.920213125491937
# Prediction_local [19.46919411]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 500, iteration = 66
# Intercept 23.894163740378467
# Prediction_local [20.57241924]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 500, iteration = 67
# Intercept 24.17595454397014
# Prediction_local [21.09559391]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 500, iteration = 68
# Intercept 26.630165754941803
# Prediction_local [21.78533147]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 500, iteration = 69
# Intercept 23.32547999578126
# Prediction_local [19.10892374]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 500, iteration = 70
# Intercept 23.414441632003513
# Prediction_local [20.33558423]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 500, iteration = 71
# Intercept 23.691000709026888
# Prediction_local [20.67245862]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 500, iteration = 72
# Intercept 25.48651868993633
# Prediction_local [20.10147201]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 500, iteration = 73
# Intercept 24.06930937251411
# Prediction_local [20.12983161]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 500, iteration = 74
# Intercept 24.6263491416599
# Prediction_local [21.71406293]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 500, iteration = 75
# Intercept 24.084335962806108
# Prediction_local [20.28528593]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 500, iteration = 76
# Intercept 22.272788940869404
# Prediction_local [20.91596276]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 500, iteration = 77
# Intercept 24.607582677602768
# Prediction_local [18.83533567]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 500, iteration = 78
# Intercept 26.75807435731791
# Prediction_local [20.54690193]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 500, iteration = 79
# Intercept 24.32291592600365
# Prediction_local [22.020763]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 500, iteration = 80
# Intercept 24.42616562380706
# Prediction_local [19.9412401]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 500, iteration = 81
# Intercept 23.49551904798066
# Prediction_local [21.49028395]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 500, iteration = 82
# Intercept 26.055076481917006
# Prediction_local [19.70610182]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 500, iteration = 83
# Intercept 25.315560313420207
# Prediction_local [20.46378157]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 500, iteration = 84
# Intercept 24.910599475718126
# Prediction_local [20.12578677]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 500, iteration = 85
# Intercept 24.682516288843328
# Prediction_local [21.35550662]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 500, iteration = 86
# Intercept 23.74067738917241
# Prediction_local [20.45516534]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 500, iteration = 87
# Intercept 23.23912958546827
# Prediction_local [20.78007845]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 500, iteration = 88
# Intercept 25.652763350850243
# Prediction_local [19.2015576]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 500, iteration = 89
# Intercept 23.302964201403388
# Prediction_local [23.32016351]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 500, iteration = 90
# Intercept 27.14816842457833
# Prediction_local [19.77300251]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 500, iteration = 91
# Intercept 25.283513558555775
# Prediction_local [19.85623145]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 500, iteration = 92
# Intercept 26.54433206371996
# Prediction_local [19.295971]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 500, iteration = 93
# Intercept 25.21337519433266
# Prediction_local [20.43160143]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 500, iteration = 94
# Intercept 25.566830472297674
# Prediction_local [20.84536654]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 500, iteration = 95
# Intercept 26.270670857537066
# Prediction_local [21.87512044]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 500, iteration = 96
# Intercept 26.32000828470363
# Prediction_local [20.75250599]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 500, iteration = 97
# Intercept 24.029907468301776
# Prediction_local [21.70258327]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 500, iteration = 98
#  C:\Users\adity\anaconda3\lib\site-packages\GPy\kern\src\stationary.py:137: RuntimeWarning:overflow encountered in square
#  C:\Users\adity\anaconda3\lib\site-packages\GPy\kern\src\stationary.py:138: RuntimeWarning:invalid value encountered in add
# Intercept 26.074288605845986
# Prediction_local [19.40640798]
# Right: 21.932999999999996
# -->> Performing experiment for LIME(gp_KL) num_samples = 500, iteration = 99
# Intercept 24.206199451008633
# Prediction_local [20.25535675]
# Right: 21.932999999999996

# %%
import pickle

data = {}

data['dict_gp_KL'] = dict_gp_KL
data['dict_gp_ard'] = dict_gp_ard
data['dict_lime'] = dict_lime

with open('data_boston.pickle', 'wb') as handle:
    pickle.dump(data, handle, protocol=pickle.HIGHEST_PROTOCOL)
